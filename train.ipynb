# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-seg.pt")

# %%
result = model.train(data="Cavity_Sediment_Segmentation\data.yaml", epochs=80, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.163 available  Update with 'pip install -U ultralytics'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\RISHIKESH\AppData\Local\Temp\ipykernel_15720\2557767404.py:1: SyntaxWarning: invalid escape sequence '\d'
#   result = model.train(data="cavity_sediment_dataset\data.yaml", epochs=80, imgsz=640)
# Ultralytics 8.3.159  Python-3.13.5 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# ...
